# %% [markdown]
# # Product Parsing
#
# Check structure after `normalize_product_record`.

# %%
import sys
sys.path.append("../")
from pathlib import Path

from ingestion.product.product_json_chunker import parse_fashion_dataset

# %%
input_path = Path("../data/raw/FashionDataset.csv")

# %%
records = parse_fashion_dataset(input_path)
len(records)
# Out:
# 4978

# %%
for record in records[:5]:
    print(record)
    print("---")
# Out:
# {'product_id': '17048614', 'product': 'Khushal K Women Black Ethnic Motifs Printed Kurta with Palazzos & With Dupatta', 'brand': 'Khushal K', 'color': 'Black', 'category': 'Kurta set', 'top_type': 'Kurta', 'bottom_type': 'Palazzos', 'dupatta': 'With dupatta', 'pattern': 'Ethnic motifs printed', 'shape': 'Anarkali', 'neck': 'Mandarin collar', 'sleeves': 'Three-quarter regular sleeves', 'length': 'Calf length', 'hemline': 'Flared', 'top_fabric': 'Viscose rayon', 'bottom_fabric': 'Viscose rayon', 'dupatta_fabric': 'Viscose rayon', 'occasion': 'Festive', 'wash_care': 'Machine wash', 'price': '5099.0', 'rating_count': '4522.0', 'avg_rating': '4.4183989385227775', 'image_url': 'http://assets.myntassets.com/assets/images/17048614/2022/2/4/b0eb9426-adf2-4802-a6b3-5dbacbc5f2511643971561167KhushalKWomenBlackEthnicMotifsAngrakhaBeadsandStonesKurtawit7.jpg', 'text': 'Product: Khushal K Women Black Ethnic Motifs Printed Kurta with Palazzos & With Dupatta\nBrand: Khushal K\nColor: Black\nCategory:
# ...
