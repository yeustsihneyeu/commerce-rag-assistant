# %% [markdown]
# # FAQ Chunking
#
# Check `Document` and result of `ConditionalFixedChunker`.

# %%
import sys
sys.path.append("../../")

from ingestion.faq.faq_chunker import split_by_docs
from ingestion.faq.faq_doc_builder import build_llama_documents
from src.core.transformers import ConditionalFixedChunker

# %%
sections = split_by_docs("../data/raw/faq.docx")
documents = build_llama_documents(sections)
len(documents)
# Out:
# 97

# %%
documents[0].text[:500], documents[0].metadata
# Out:
# ('How to register on HopShop\nIf you want to be an active user of HopShop, register in a few simple steps. It is free of charge.\nCheck how to register\nwith an email address\nwith a Google or Facebook account\nwith a phone number.',
#  {'section_title': 'How to register on HopShop',
#   'source_type': 'faq',
#   'source_file': 'faq.docx',
#   'section_id': 1})

# %%
chunker = ConditionalFixedChunker()
nodes = chunker(documents)
len(nodes)
# Out:
# 101

# %%
for node in nodes[:5]:
    print(node.node_id)
    print(node.text[:200])
    print(node.metadata)
    print("---")
# Out:
# 5c535202-605f-405e-a831-52fab4cbe917
# How to register on HopShop
# If you want to be an active user of HopShop, register in a few simple steps. It is free of charge.
# Check how to register
# with an email address
# with a Google or Facebook acco
# {'section_title': 'How to register on HopShop', 'source_type': 'faq', 'source_file': 'faq.docx', 'section_id': 1}
# ---
# 08d57e59-96a2-4811-be77-c79e2daafe4d
# How to register with an email
# Open the registration page. Choose whether you want to hold a regular account or a business account.
# Enter your email address and create a password.
# Determine whether you
# {'section_title': 'How to register with an email', 'source_type': 'faq', 'source_file': 'faq.docx', 'section_id': 2}
# ---
# 517b64ae-83ca-484d-bcd1-47831f796bf0
# How to register with Google or Facebook account
# Open the sign in page.
# Select signing in through Facebook or Google.
# Sign in to your Facebook or Google account. Then, we will automatically redirect yo
# {'section_title': 'How to register with Google or Facebook account', 'source_type': 'faq', 'source_file': 'faq.docx', 'section_id': 3}
# ---
# b1f4b890-ac89-48fe-84bc-8d78fa1cdfdd
# Signing in with a password and email address
# If you want to be able to sign in to your account with an email address and password, too ― set a password in the Sign-in and Password tab.
# {'section_title': 'Signing in with a password and email address', 'source_type': 'faq', 'source_file': 'faq.docx', 'section_id': 4}
# ---
# fc4ac49b-377b-4b89-81ee-95a94fccecbf
# How to register with your phone number
# Open the registration page. Select whether you want to create a regular or business account.
# Select Contact number and enter your phone number.
# Declare if you ha
# {'section_title': 'How to register with your phone number', 'source_type': 'faq', 'source_file': 'faq.docx', 'section_id': 5, 'parent_node_id': '2bb1b5cb-635b-42ee-ba08-4b9f96e70f39', 'subchunk_id': 1}
# ---
