# %% [markdown]
# # Product Parsing
#
# Check structure after `normalize_product_record`.

# %%
import sys
sys.path.append("../../")
from pathlib import Path
import json

from ingestion.product.product_json_chunker import parse_product_dataset

# %%
input_path = Path("../data/raw/product.csv")

# %%
records = parse_product_dataset(input_path)
len(records)
# Out:
# 4973

# %%
for record in records[:5]:
    print(json.dumps(record, indent=2, ensure_ascii=False))
    print("---")
# Out:
# {
#   "product_id": "17048614",
#   "product": "Khushal K Women Black Ethnic Motifs Printed Kurta with Palazzos & With Dupatta",
#   "brand": "Khushal K",
#   "color": "Black",
#   "category": "Kurta set",
#   "top_type": "Kurta",
#   "bottom_type": "Palazzos",
#   "dupatta": "With dupatta",
#   "pattern": "Ethnic motifs printed",
#   "shape": "Anarkali",
#   "neck": "Mandarin collar",
#   "sleeves": "Three-quarter regular sleeves",
#   "length": "Calf length",
#   "hemline": "Flared",
#   "top_fabric": "Viscose rayon",
#   "bottom_fabric": "Viscose rayon",
#   "dupatta_fabric": "Viscose rayon",
#   "occasion": "Festive",
#   "wash_care": "Machine wash",
#   "price": "5099.0",
#   "rating_count": "4522.0",
#   "avg_rating": "4.4183989385227775",
#   "image_url": "http://assets.myntassets.com/assets/images/17048614/2022/2/4/b0eb9426-adf2-4802-a6b3-5dbacbc5f2511643971561167KhushalKWomenBlackEthnicMotifsAngrakhaBeadsandStonesKurtawit7.jpg",
#   "text": "Product: Khushal K Women Black Ethnic Motifs Printed Kurta with Palazzos & With Dupatta\nBrand: Khushal K\nColor: Black\nCategory: Kurta set\nTop type: Kurta\nBottom type: Palazzos\nDupatta: With dupatta\nPattern: Ethnic motifs printed\nShape: Anarkali\nNeck: Mandarin collar\nSleeves: Three-quarter regular sleeves\nLength: Calf length\nHemline: Flared\nTop fabric: Viscose rayon\nBottom fabric: Viscose rayon\nDupatta fabric: Viscose rayon\nOccasion: Festive\nWash care: Machine wash",
#   "attributes": {
#     "Body Shape ID": "443,333,324,424",
#     "Body or Garment Size": "Garment Measurements in",
#     "Bottom Closure": "Slip-On",
#     "Bottom Fabric": "Viscose Rayon",
#     "Bottom Pattern": "Printed",
#     "Bottom Type": "Palazzos",
#     "Dupatta": "With Dupatta",
#     "Dupatta Border": "Solid",
#     "Dupatta Fabric": "Viscose Rayon",
#     "Dupatta Pattern": "Printed",
#     "Main Trend": "Indie Prints",
#     "Neck": "Mandarin Collar",
#     "Occasion": "Festive",
#     "Pattern Coverage": "Placement",
#     "Print or Pattern Type": "Ethnic Motifs",
#     "Sleeve Length": "Three-Quarter Sleeves",
#     "Sleeve Styling": "Regular Sleeves",
#     "Stitch": "Ready to Wear",
#     "Sustainable": "Regular",
#     "Technique": "Screen",
#     "Top Design Styling": "Regular",
#     "Top Fabric": "Viscose Rayon",
#     "Top Hemline": "Flared",
#     "Top Length": "Calf Length",
#     "Top Pattern": "Printed",
#     "Top Shape": "Anarkali",
#     "Top Type": "Kurta",
#     "Waistband": "Elasticated",
#     "Wash Care": "Machine Wash",
#     "Weave Pattern": "Regular",
#     "Weave Type": "Machine Weave"
#   }
# }
# ---
# {
#   "product_id": "16524740",
#   "product": "InWeave Women Orange Solid Kurta with Palazzos & Floral Print Dupatta",
#   "brand": "InWeave",
#   "color": "Orange",
#   "category": "Kurta set",
#   "top_type": "Kurta",
#   "bottom_type": "Palazzos",
#   "dupatta": "With dupatta",
#   "pattern": "Solid",
#   "shape": "A-line",
#   "neck": "Square neck",
#   "sleeves": "Sleeveless shoulder straps",
#   "length": "Calf length",
#   "hemline": "Flared",
#   "top_fabric": "Viscose rayon",
#   "bottom_fabric": "Viscose rayon",
#   "dupatta_fabric": "Organza",
#   "occasion": "Fusion",
#   "wash_care": "Hand wash",
#   "price": "5899.0",
#   "rating_count": "1081.0",
#   "avg_rating": "4.119333950046253",
#   "image_url": "http://assets.myntassets.com/assets/images/16524740/2021/12/29/17ab2ac8-2e60-422d-9d20-2527415932361640754214931-STRAPPY-SET-IN-ORANGE-WITH-ORGANZA-DUPATTA-5961640754214349-2.jpg",
#   "text": "Product: InWeave Women Orange Solid Kurta with Palazzos & Floral Print Dupatta\nBrand: InWeave\nColor: Orange\nCategory: Kurta set\nTop type: Kurta\nBottom type: Palazzos\nDupatta: With dupatta\nPattern: Solid\nShape: A-line\nNeck: Square neck\nSleeves: Sleeveless shoulder straps\nLength: Calf length\nHemline: Flared\nTop fabric: Viscose rayon\nBottom fabric: Viscose rayon\nDupatta fabric: Organza\nOccasion: Fusion\nWash care: Hand wash",
#   "attributes": {
#     "Body Shape ID": "443,333,324,424",
#     "Body or Garment Size": "Garment Measurements in",
#     "Bottom Closure": "Zip",
#     "Bottom Fabric": "Viscose Rayon",
#     "Bottom Pattern": "Solid",
#     "Bottom Type": "Palazzos",
#     "Dupatta": "With Dupatta",
#     "Dupatta Border": "Printed",
#     "Dupatta Fabric": "Organza",
#     "Dupatta Pattern": "Printed",
#     "Neck": "Square Neck",
#     "Occasion": "Fusion",
#     "Print or Pattern Type": "Solid",
#     "Sleeve Length": "Sleeveless",
#     "Sleeve Styling": "Shoulder Straps",
#     "Stitch": "Ready to Wear",
#     "Sustainable": "Regular",
#     "Top Design Styling": "Regular",
#     "Top Fabric": "Viscose Rayon",
#     "Top Hemline": "Flared",
#     "Top Length": "Calf Length",
#     "Top Pattern": "Solid",
#     "Top Shape": "A-Line",
#     "Top Type": "Kurta",
#     "Waistband": "Elasticated",
#     "Wash Care": "Hand Wash",
#     "Weave Pattern": "Regular",
#     "Weave Type": "Machine Weave"
#   }
# }
# ---
# {
#   "product_id": "16331376",
#   "product": "Anubhutee Women Navy Blue Ethnic Motifs Embroidered Thread Work Kurta with Trousers & With Dupatta",
#   "brand": "Anubhutee",
#   "color": "Navy Blue",
#   "category": "Kurta set",
#   "top_type": "Kurta",
#   "bottom_type": "Trousers",
#   "dupatta": "With dupatta",
#   "pattern": "Ethnic motifs embroidered",
#   "shape": "A-line",
#   "neck": "Round neck",
#   "sleeves": "Three-quarter no sleeves",
#   "length": "Above knee",
#   "hemline": "Flared",
#   "top_fabric": "Viscose rayon",
#   "bottom_fabric": "Viscose rayon",
#   "dupatta_fabric": "Voile",
#   "occasion": "Daily",
#   "wash_care": "Hand wash",
#   "price": "4899.0",
#   "rating_count": "1752.0",
#   "avg_rating": "4.161529680365297",
#   "image_url": "http://assets.myntassets.com/assets/images/16331376/2021/12/2/b8c4f90f-683c-48d2-b8ac-19891a87c0651638428628378KurtaSets1.jpg",
#   "text": "Product: Anubhutee Women Navy Blue Ethnic Motifs Embroidered Thread Work Kurta with Trousers & With Dupatta\nBrand: Anubhutee\nColor: Navy Blue\nCategory: Kurta set\nTop type: Kurta\nBottom type: Trousers\nDupatta: With dupatta\nPattern: Ethnic motifs embroidered\nShape: A-line\nNeck: Round neck\nSleeves: Three-quarter no sleeves\nLength: Above knee\nHemline: Flared\nTop fabric: Viscose rayon\nBottom fabric: Viscose rayon\nDupatta fabric: Voile\nOccasion: Daily\nWash care: Hand wash",
#   "attributes": {
#     "Body Shape ID": "333,424",
#     "Body or Garment Size": "Garment Measurements in",
#     "Bottom Closure": "Slip-On",
#     "Bottom Fabric": "Viscose Rayon",
#     "Bottom Pattern": "Printed",
#     "Bottom Type": "Trousers",
#     "Dupatta": "With Dupatta",
#     "Dupatta Border": "Tassels",
#     "Dupatta Fabric": "Voile",
#     "Dupatta Pattern": "Embroidered",
#     "Neck": "Round Neck",
#     "Occasion": "Daily",
#     "Ornamentation": "Thread Work",
#     "Pattern Coverage": "Large",
#     "Print or Pattern Type": "Ethnic Motifs",
#     "Sleeve Length": "Three-Quarter Sleeves",
#     "Sleeve Styling": "No Sleeves",
#     "Stitch": "Ready to Wear",
#     "Sustainable": "Regular",
#     "Technique": "Foil",
#     "Top Design Styling": "Regular",
#     "Top Fabric": "Viscose Rayon",
#     "Top Hemline": "Flared",
#     "Top Length": "Above Knee",
#     "Top Pattern": "Embroidered",
#     "Top Shape": "A-Line",
#     "Top Type": "Kurta",
#     "Waistband": "Elasticated",
#     "Wash Care": "Hand Wash",
#     "Weave Pattern": "Regular",
#     "Weave Type": "Machine Weave"
#   }
# }
# ---
# {
#   "product_id": "14709966",
#   "product": "Nayo Women Red Floral Printed Kurta With Trouser & Dupatta",
#   "brand": "Nayo",
#   "color": "Red",
#   "category": "Kurta set",
#   "top_type": "Kurta",
#   "bottom_type": "Trousers",
#   "dupatta": "With dupatta",
#   "pattern": "Ethnic motifs printed",
#   "shape": "Anarkali",
#   "neck": "Round neck",
#   "sleeves": "Three-quarter regular sleeves",
#   "length": "Calf length",
#   "hemline": "Flared",
#   "top_fabric": "Pure cotton",
#   "bottom_fabric": "Pure cotton",
#   "dupatta_fabric": "Cotton blend",
#   "occasion": "Daily",
#   "wash_care": "Hand wash",
#   "price": "3699.0",
#   "rating_count": "4113.0",
#   "avg_rating": "4.088986141502553",
#   "image_url": "http://assets.myntassets.com/assets/images/14709966/2021/7/10/d2407657-1f04-4d13-9f52-9e134050489b1625905793495-Nayo-Women-Red-Ethnic-Motifs-Printed-Empire-Pure-Cotton-Kurt-1.jpg",
#   "text": "Product: Nayo Women Red Floral Printed Kurta With Trouser & Dupatta\nBrand: Nayo\nColor: Red\nCategory: Kurta set\nTop type: Kurta\nBottom type: Trousers\nDupatta: With dupatta\nPattern: Ethnic motifs printed\nShape: Anarkali\nNeck: Round neck\nSleeves: Three-quarter regular sleeves\nLength: Calf length\nHemline: Flared\nTop fabric: Pure cotton\nBottom fabric: Pure cotton\nDupatta fabric: Cotton blend\nOccasion: Daily\nWash care: Hand wash",
#   "attributes": {
#     "Body Shape ID": "333,424",
#     "Body or Garment Size": "Garment Measurements in",
#     "Bottom Closure": "Slip-On",
#     "Bottom Fabric": "Pure Cotton",
#     "Bottom Pattern": "Printed",
#     "Bottom Type": "Trousers",
#     "Dupatta": "With Dupatta",
#     "Dupatta Border": "Printed",
#     "Dupatta Fabric": "Cotton Blend",
#     "Dupatta Pattern": "Printed",
#     "Neck": "Round Neck",
#     "Occasion": "Daily",
#     "Pattern Coverage": "Large",
#     "Print or Pattern Type": "Ethnic Motifs",
#     "Sleeve Length": "Three-Quarter Sleeves",
#     "Sleeve Styling": "Regular Sleeves",
#     "Slit Detail": "Front Slit",
#     "Stitch": "Ready to Wear",
#     "Sustainable": "Regular",
#     "Top Design Styling": "Empire",
#     "Top Fabric": "Pure Cotton",
#     "Top Hemline": "Flared",
#     "Top Length": "Calf Length",
#     "Top Pattern": "Printed",
#     "Top Shape": "Anarkali",
#     "Top Type": "Kurta",
#     "Waistband": "Elasticated",
#     "Wash Care": "Hand Wash",
#     "Weave Pattern": "Regular",
#     "Weave Type": "Machine Weave"
#   }
# }
# ---
# {
#   "product_id": "11056154",
#   "product": "AHIKA Women Black & Green Printed Straight Kurta",
#   "brand": "AHIKA",
#   "color": "Black",
#   "pattern": "Ethnic motifs printed",
#   "shape": "Straight",
#   "neck": "Round neck",
#   "sleeves": "Three-quarter regular sleeves",
#   "length": "Calf length",
#   "hemline": "Straight",
#   "top_fabric": "Cotton",
#   "occasion": "Daily",
#   "wash_care": "Machine wash",
#   "price": "1350.0",
#   "rating_count": "21274.0",
#   "avg_rating": "3.978377362038169",
#   "image_url": "http://assets.myntassets.com/assets/images/11056154/2019/12/5/30b0017d-7e72-4d40-9633-ef78d01719741575541717470-AHIKA-Women-Black--Green-Printed-Straight-Kurta-990157554171-1.jpg",
#   "text": "Product: AHIKA Women Black & Green Printed Straight Kurta\nBrand: AHIKA\nColor: Black\nPattern: Ethnic motifs printed\nShape: Straight\nNeck: Round neck\nSleeves: Three-quarter regular sleeves\nLength: Calf length\nHemline: Straight\nTop fabric: Cotton\nOccasion: Daily\nWash care: Machine wash",
#   "attributes": {
#     "Body Shape ID": "424",
#     "Body or Garment Size": "Garment Measurements in",
#     "Colour Family": "Monochrome",
#     "Design Styling": "Regular",
#     "Fabric": "Cotton",
#     "Fabric Purity": "Pure",
#     "Hemline": "Straight",
#     "Length": "Calf Length",
#     "Neck": "Round Neck",
#     "Occasion": "Daily",
#     "Pattern": "Printed",
#     "Print or Pattern Type": "Ethnic Motifs",
#     "Shape": "Straight",
#     "Sleeve Length": "Three-Quarter Sleeves",
#     "Sleeve Styling": "Regular Sleeves",
#     "Slit Detail": "Side Slits",
#     "Stitch": "Ready to Wear",
#     "Wash Care": "Machine Wash",
#     "Weave Pattern": "Regular",
#     "Weave Type": "Machine Weave"
#   }
# }
# ---
